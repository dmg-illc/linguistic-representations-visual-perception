# %% [markdown]
# # Visualise Encoding Results
#
# This notebook contains the code to reproduce the main plots summarising brain encoding results.

# %%
from src.paths import ROOT 
from src.utils import *
from src.brain_encoding.manage_encoding_results import BrainPlotManager

# %%
pm = BrainPlotManager()
for roi in ['places', 'bodies','faces']:
    pm.comprehensive_lm_plot_by_encoder(target_roi=roi, save=False)

# %%
pm = BrainPlotManager()
for roi in pm.brain_rois:
    pm.vf_plot(target_roi=roi, save=False)

# %%
pm = BrainPlotManager()

embedder = 'qwen3'
pm.linechart_intrinsic_dimensionality(embedder, 'all', axspan=(24.5,28.5), save=True, file_name=f'enc_id_{embedder}')

# %%
pm = BrainPlotManager()

embedder = 'kalm'
pm.linechart_intrinsic_dimensionality(embedder, 'all', axspan=(26.5,35.5), save=True, file_name=f'enc_id_{embedder}')
