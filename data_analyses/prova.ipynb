# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/anna/Documents/Code/linguistic-representations-visual-perception/results/lm_judg_rsa_results.csv')

# %%
df.head()
# Out:
#           enc_name caption_type  participant        rs
# 0  Qwen3 Embedding         COCO            1  0.188689
# 1  Qwen3 Embedding         COCO            2  0.200991
# 2  Qwen3 Embedding         COCO            3  0.148461
# 3  Qwen3 Embedding         COCO            4  0.176529
# 4  Qwen3 Embedding         COCO            5  0.213198

# %%
df.enc_name.unique()
# Out:
# array(['Qwen3 Embedding', 'Kalm Embedding', 'BERT', 'Llama3', 'GPT-2'],
#       dtype=object)

# %%
df.caption_type.unique()
# Out:
# array(['MS COCO', 'LLaVA-OV', 'Phi-4', 'Pixtral', 'Qwen2.5-VL', 'Molmo'],
#       dtype=object)

# %%
df = df.loc[(df.caption_type!='LocNarr') & (df.caption_type!='MS COCO avg.'), :]

# %%
df.caption_type[df.caption_type=='LLaVA'] = 'LLaVA-OV'
# Out:
# /var/folders/58/wcp587g90ng_jrcjxynmygj40000gn/T/ipykernel_65168/2224152793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.caption_type[df.caption_type=='LLaVA'] = 'LLaVA-OV'

# %%
df.caption_type[df.caption_type=='COCO'] = 'MS COCO'
# Out:
# /var/folders/58/wcp587g90ng_jrcjxynmygj40000gn/T/ipykernel_65168/2663555272.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.caption_type[df.caption_type=='COCO'] = 'MS COCO'

# %%
df.enc_name[df.enc_name=='Qwen3 Embeddings'] = 'Qwen3 Embedding'

# %%
df.enc_name[df.enc_name=='Kalm Embeddings'] = 'Kalm Embedding'
# Out:
# /var/folders/58/wcp587g90ng_jrcjxynmygj40000gn/T/ipykernel_65168/3779882659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.enc_name[df.enc_name=='Kalm Embeddings'] = 'Kalm Embedding'

# %%
df.to_csv('/Users/anna/Documents/Code/linguistic-representations-visual-perception/results/lm_judg_rsa_results.csv', index=False)
